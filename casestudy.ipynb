# %% [markdown]
# # May-June 3 months expiry data(election period) bank nifty call/put options

# %%
import pandas as pd

# Load historical data and options data
historical_data = pd.read_csv('datasets/Historical_data.csv')
options_data = pd.read_csv('datasets/new_options_data.csv')
options_data_put = pd.read_csv('datasets/new_options_data_put.csv')

# Remove blank space from column names in options data
options_data.columns = [col.strip() for col in options_data.columns]
options_data_put.columns = [col.strip() for col in options_data_put.columns]

# Remove rows with values=nan(missing values) from historical data
historical_data = historical_data.dropna()

# Select relevant columns from options data and drop rows with values=nan(missing values)
options_data = options_data[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']].dropna()

# Convert Expiry and Date columns to datetime format
options_data['Expiry'] = pd.to_datetime(options_data['Expiry'], format='%d%b%Y')
options_data['Date'] = pd.to_datetime(options_data['Date'], format='%d%b%Y')

# Select relevant columns from put options data and drop rows with missing values
options_data_put = options_data_put[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']].dropna()

# Convert Expiry  and Date columns to datetime format for put options data
options_data_put['Expiry'] = pd.to_datetime(options_data_put['Expiry'], format='%d%b%Y')
options_data_put['Date'] = pd.to_datetime(options_data_put['Date'], format='%d%b%Y')

# Print column names for debugging
#print(options_data_put.columns)
#print(options_data.columns)

# Concatenate(Merge) options data and put options data
options_data = pd.concat([options_data, options_data_put])

# Sort options data by Date and reset index
options_data = options_data.sort_values(by='Date').reset_index(drop=True)

# Display the final combined options data
print(options_data)
# Out:
#          Symbol       Date     Expiry Option type  Strike Price    Close
# 0     BANKNIFTY 2024-05-02 2024-07-31          PE       47400.0  1089.15
# 1     BANKNIFTY 2024-05-02 2024-07-31          PE       51000.0  2300.00
# 2     BANKNIFTY 2024-05-02 2024-07-31          PE       50900.0  2868.60
# 3     BANKNIFTY 2024-05-02 2024-07-31          PE       50800.0  2804.20
# 4     BANKNIFTY 2024-05-02 2024-07-31          PE       50700.0  2740.60
# ...         ...        ...        ...         ...           ...      ...
# 4689  BANKNIFTY 2024-06-05 2024-07-31          CE       46400.0  3587.25
# 4690  BANKNIFTY 2024-06-05 2024-07-31          CE       46200.0  3797.65
# 4691  BANKNIFTY 2024-06-05 2024-07-31          CE       46100.0  3848.70
# 4692  BANKNIFTY 2024-06-05 2024-07-31          CE       49000.0  1598.45
# 4693  BANKNIFTY 2024-06-05 2024-07-31          CE       41000.0  8034.10
#
# [4694 rows x 6 columns]

# %% [markdown]
# # Here I am testing how much loss and profit will I make using the model's output

# %% [markdown]
# # May-June 1 month expiry(election period) bank nifty

# %%
# Load historical data and options data
historical_data = pd.read_csv('datasets/Historical_data.csv')
options_data = pd.read_csv('datasets/options_data.csv')
options_data_put = pd.read_csv('datasets/options_data_put.csv')

# Remove blank space from column names in options data
options_data.columns = [col.strip() for col in options_data.columns]
options_data_put.columns = [col.strip() for col in options_data_put.columns]

# Remove rows with values=nan(missing values) from historical data
historical_data = historical_data.dropna()

# Select relevant columns from options data and drop rows with values=nan(missing values)
options_data = options_data[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']].dropna()

# Convert Expiry and Date columns to datetime format
options_data['Expiry'] = pd.to_datetime(options_data['Expiry'], format='%d-%b-%Y')
options_data['Date'] = pd.to_datetime(options_data['Date'], format='%d-%b-%Y')

# Select relevant columns from put options data and drop rows with missing values
options_data_put = options_data_put[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']].dropna()

# Convert Expiry  and Date columns to datetime format for put options data
options_data_put['Expiry'] = pd.to_datetime(options_data_put['Expiry'], format='%d%b%Y')
options_data_put['Date'] = pd.to_datetime(options_data_put['Date'], format='%d%b%Y')

# Print column names for debugging
#print(options_data_put.columns)
#print(options_data.columns)

# Concatenate(Merge) options data and put options data
options_data = pd.concat([options_data, options_data_put])

# Sort options data by Date and reset index
options_data = options_data.sort_values(by='Date').reset_index(drop=True)

# Display the final combined options data
print(options_data)
# Out:
#          Symbol       Date     Expiry Option type  Strike Price    Close
# 0     BANKNIFTY 2024-05-02 2024-06-05          CE       42000.0  7691.10
# 1     BANKNIFTY 2024-05-02 2024-06-05          PE       47500.0   340.95
# 2     BANKNIFTY 2024-05-02 2024-06-05          PE       47600.0   363.55
# 3     BANKNIFTY 2024-05-02 2024-06-05          PE       47700.0   387.20
# 4     BANKNIFTY 2024-05-02 2024-06-05          PE       47800.0   413.90
# ...         ...        ...        ...         ...           ...      ...
# 4673  BANKNIFTY 2024-06-04 2024-06-05          CE       51600.0    48.45
# 4674  BANKNIFTY 2024-06-04 2024-06-05          CE       51700.0    46.40
# 4675  BANKNIFTY 2024-06-04 2024-06-05          CE       51800.0    43.75
# 4676  BANKNIFTY 2024-06-04 2024-06-05          CE       50600.0    74.80
# 4677  BANKNIFTY 2024-06-04 2024-06-05          PE       58500.0  8697.65
#
# [4678 rows x 6 columns]

# %% [markdown]
# # Jan-Feb one month expiry

# %%
options_data = pd.read_csv('datasets/jan_feb_options_data.csv')
historical_data = pd.read_csv('datasets/jan_feb_Historical_data.csv')
options_data.columns = [column.strip() for column in options_data.columns]
# historical_data = [column.strip() for column in historical_data.columns]
historical_data = pd.DataFrame(historical_data)
historical_data = historical_data.dropna()

# print(historical_data.columns)

options_data = pd.DataFrame(options_data[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']])
# print(options_data)
options_data_put = pd.read_csv('datasets/jan_feb_options_data_put.csv')
options_data_put.columns = [column.strip() for column in options_data_put.columns]
options_data = options_data.dropna()
# options_data_put = options_data_put.dropna()

options_data["Expiry"] = pd.to_datetime(options_data['Expiry'], format='%d%b%Y')
options_data["Date"] = pd.to_datetime(options_data['Date'], format='%d%b%Y')

options_data_put = pd.DataFrame(options_data_put[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']])
options_data_put = options_data_put.dropna()
options_data_put["Expiry"] = pd.to_datetime(options_data_put['Expiry'], format='%d%b%Y')
options_data_put["Date"] = pd.to_datetime(options_data_put['Date'], format='%d%b%Y')

print(options_data_put.columns)
print(options_data.columns)

options_data = pd.concat([options_data, options_data_put])
# print(options_data)

options_data = options_data.sort_values(by='Date').reset_index(drop=True)
print(options_data)
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close'], dtype='object')
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close'], dtype='object')
#          Symbol       Date     Expiry Option type  Strike Price    Close
# 0     BANKNIFTY 2024-01-04 2024-02-07          CE       41500.0  6499.10
# 1     BANKNIFTY 2024-01-04 2024-02-07          PE       47500.0   856.05
# 2     BANKNIFTY 2024-01-04 2024-02-07          PE       47400.0   813.60
# 3     BANKNIFTY 2024-01-04 2024-02-07          PE       47300.0   772.55
# 4     BANKNIFTY 2024-01-04 2024-02-07          PE       47200.0   732.90
# ...         ...        ...        ...         ...           ...      ...
# 3853  BANKNIFTY 2024-02-01 2024-02-07          CE       48900.0    14.55
# 3854  BANKNIFTY 2024-02-01 2024-02-07          CE       49000.0    13.40
# 3855  BANKNIFTY 2024-02-01 2024-02-07          CE       49100.0    12.15
# 3856  BANKNIFTY 2024-02-01 2024-02-07          CE       46500.0   336.30
# 3857  BANKNIFTY 2024-02-01 2024-02-07          PE       55500.0  9425.00
#
# [3858 rows x 6 columns]

# %%
# Calculating the percentage of times the relative error is 0.01 or less for each model
bs_low_error_percentage = (results_df['BS Relative Error'] <= 0.1).mean() * 100
binomial_low_error_percentage = (results_df['Binomial Relative Error'] <= 0.1).mean() * 100

# Print the results
print(f"Percentage of times Black-Scholes model has ≈0.1 or less error: {bs_low_error_percentage:.2f}%")
print(f"Percentage of times Binomial model has ≈0.1 or less error: {binomial_low_error_percentage:.2f}%")
# Out:
# Percentage of times Black-Scholes model has ≈0.1 or less error: 32.38%
# Percentage of times Binomial model has ≈0.1 or less error: 31.87%

# %% [markdown]
# # now we will analyse for low volatile stock, and see the effects for both the models

# %% [markdown]
# # nifty 50 around 2016-17 and 2 expiry periods, 1month, 3 months

# %%
options_data = pd.read_csv('datasets/nifty50_options_data.csv')
historical_data = pd.read_csv('datasets/nifty50_historical.csv')
options_data.columns = [column.strip() for column in options_data.columns]
historical_data.columns = [column.strip() for column in historical_data.columns]
historical_data = pd.DataFrame(historical_data)
historical_data = historical_data.dropna()

# print(historical_data.columns)

options_data = pd.DataFrame(options_data[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']])
# print(options_data)
options_data_put = pd.read_csv('datasets/nifty50_options_data_put.csv')
options_data_put.columns = [column.strip() for column in options_data_put.columns]
options_data = options_data.dropna()
# options_data_put = options_data_put.dropna()

options_data["Expiry"] = pd.to_datetime(options_data['Expiry'], format='%d%b%Y')
options_data["Date"] = pd.to_datetime(options_data['Date'], format='%d%b%Y')

options_data_put = pd.DataFrame(options_data_put[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']])
options_data_put = options_data_put.dropna()
options_data_put["Expiry"] = pd.to_datetime(options_data_put['Expiry'], format='%d%b%Y')
options_data_put["Date"] = pd.to_datetime(options_data_put['Date'], format='%d%b%Y')

print(options_data_put.columns)
print(options_data.columns)

options_data = pd.concat([options_data, options_data_put])
# print(options_data)

options_data = options_data.sort_values(by='Date').reset_index(drop=True)
print(options_data)
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close'], dtype='object')
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close'], dtype='object')
#      Symbol       Date     Expiry Option type  Strike Price    Close
# 0     NIFTY 2016-12-01 2017-01-25          CE       10000.0     1.50
# 1     NIFTY 2016-12-01 2017-01-25          PE        7250.0     0.70
# 2     NIFTY 2016-12-01 2017-01-25          PE        7300.0    19.30
# 3     NIFTY 2016-12-01 2017-01-25          PE        7350.0     1.30
# 4     NIFTY 2016-12-01 2017-01-25          PE        7400.0    24.80
# ...     ...        ...        ...         ...           ...      ...
# 3303  NIFTY 2016-12-30 2017-01-25          CE        8800.0     2.35
# 3304  NIFTY 2016-12-30 2017-01-25          CE        8850.0     1.95
# 3305  NIFTY 2016-12-30 2017-01-25          CE        8900.0     1.40
# 3306  NIFTY 2016-12-30 2017-01-25          CE        8550.0    10.95
# 3307  NIFTY 2016-12-30 2017-01-25          PE        9950.0  1181.45
#
# [3308 rows x 6 columns]

# %%
options_data = pd.read_csv('datasets/high_expiry_nifty50_options_data.csv')
historical_data = pd.read_csv('datasets/nifty50_historical.csv')
options_data.columns = [column.strip() for column in options_data.columns]
historical_data.columns = [column.strip() for column in historical_data.columns]
historical_data = pd.DataFrame(historical_data)
historical_data = historical_data.dropna()

# print(historical_data.columns)

options_data = pd.DataFrame(options_data[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']])
# print(options_data)
options_data_put = pd.read_csv('datasets/high_expiry_options_data_put.csv')
options_data_put.columns = [column.strip() for column in options_data_put.columns]
options_data = options_data.dropna()
# options_data_put = options_data_put.dropna()

options_data["Expiry"] = pd.to_datetime(options_data['Expiry'], format='%d%b%Y')
options_data["Date"] = pd.to_datetime(options_data['Date'], format='%d%b%Y')

options_data_put = pd.DataFrame(options_data_put[['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close']])
options_data_put = options_data_put.dropna()
options_data_put["Expiry"] = pd.to_datetime(options_data_put['Expiry'], format='%d%b%Y')
options_data_put["Date"] = pd.to_datetime(options_data_put['Date'], format='%d%b%Y')

print(options_data_put.columns)
print(options_data.columns)

options_data = pd.concat([options_data, options_data_put])
# print(options_data)

options_data = options_data.sort_values(by='Date').reset_index(drop=True)
print(options_data)
# Out:
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close'], dtype='object')
# Index(['Symbol', 'Date', 'Expiry', 'Option type', 'Strike Price', 'Close'], dtype='object')
#      Symbol       Date     Expiry Option type  Strike Price    Close
# 0     NIFTY 2016-12-01 2017-03-30          CE       10000.0     7.50
# 1     NIFTY 2016-12-01 2017-03-30          PE        6500.0    82.05
# 2     NIFTY 2016-12-01 2017-03-30          PE        6400.0    70.00
# 3     NIFTY 2016-12-01 2017-03-30          PE        6300.0    59.35
# 4     NIFTY 2016-12-01 2017-03-30          PE        6200.0    50.00
# ...     ...        ...        ...         ...           ...      ...
# 2871  NIFTY 2016-12-30 2017-03-30          CE        8350.0   216.75
# 2872  NIFTY 2016-12-30 2017-03-30          CE        8400.0   152.70
# 2873  NIFTY 2016-12-30 2017-03-30          CE        8450.0   178.45
# 2874  NIFTY 2016-12-30 2017-03-30          CE        8000.0   383.20
# 2875  NIFTY 2016-12-30 2017-03-30          PE        9900.0  1616.95
#
# [2876 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm

log_returns = np.log(historical_data["Close"] / historical_data["Close"].shift(1))
annual_volatility = log_returns.std() * np.sqrt(252)  # Annualizing the standard deviation
print(annual_volatility)
# Define Black-Scholes model
def black_scholes(S, K, T, r, sigma, option_type='CE'):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    if option_type == 'CE':
        price = S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    else:
        price = K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)
    return price

# Define Binomial model
import numpy as np

def binomial_model(S, K, T, r, sigma, steps=10, option_type='CE'):
    dt = T / steps
    u = np.exp(sigma * np.sqrt(dt))
    d = 1 / u
    p = (np.exp(r * dt) - d) / (u - d)
    discount_factor = np.exp(-r * dt)
    
    # Initialize asset prices at maturity
    prices = np.zeros(steps + 1)
    for i in range(steps + 1):
        prices[i] = S * (u ** (steps - i)) * (d ** i)
    
    # Initialize option values at maturity
    if option_type == 'CE':
        option_values = np.maximum(prices - K, 0)
    else:
        option_values = np.maximum(K - prices, 0)
    
    # Backward induction for option price
    for i in range(steps - 1, -1, -1):
        option_values = discount_factor * (p * option_values[:-1] + (1 - p) * option_values[1:])
        
    return option_values[0]


# Analysis parameters
r = 0.0676 # Risk-free rate(saw from government bonds data from internet around the 1 month period we are taking into account)
current_index_price = historical_data["Close"].iloc[-1]  # Most recent index price

# Comparing model prices to market prices
results=[]

for index, row in options_data.iterrows():
    S = current_index_price
    K = row['Strike Price']
    T = (row['Expiry'] - row['Date']).days / 365.0
    if T == 0:
        print(row['Date'])
    market_price = row['Close']
    option_type = row['Option type']

    bs_price = black_scholes(S, K, T, r, annual_volatility, option_type)
    bin_price = binomial_model(S, K, T, r, annual_volatility, option_type=option_type)

    results.append({
        'Type': option_type,
        'Strike': K,
        'Expiry': row['Expiry'],
        'Market Price': market_price,
        'BS Price': bs_price,
        'Binomial Price': bin_price,
        'BS Error': abs(bs_price - market_price),
        'Binomial Error': abs(bin_price - market_price),
        'Date': row['Date'],
        '% Binomial Error': (bin_price-market_price)/market_price,
        '% BS Error': (bs_price-market_price)/market_price
    })

results_df = pd.DataFrame(results)

print(results_df)

# Summary statistics
print("Mean Error Black-Scholes: ", results_df['% BS Error'].mean())
print("Mean Error Binomial: ", results_df['% Binomial Error'].mean())
# Out:
# 0.17179820185201097
#      Type   Strike     Expiry  Market Price     BS Price  Binomial Price  \
# 0      PE  47400.0 2024-07-31       1089.15   690.448742      720.434986
# 1      PE  51000.0 2024-07-31       2300.00  2295.817792     2315.506911
# 2      PE  50900.0 2024-07-31       2868.60  2235.361621     2260.204969
# 3      PE  50800.0 2024-07-31       2804.20  2175.774212     2204.903028
# 4      PE  50700.0 2024-07-31       2740.60  2117.062683     2149.601087
# ...   ...      ...        ...           ...          ...             ...
# 4689   CE  46400.0 2024-07-31       3587.25  3409.177551     3417.331640
# 4690   CE  46200.0 2024-07-31       3797.65  3574.700906     3587.084170
# 4691   CE  46100.0 2024-07-31       3848.70  3658.616309     3671.960435
# 4692   CE  49000.0 2024-07-31       1598.45  1608.246424     1581.944946
# 4693   CE  41000.0 2024-07-31       8034.10  8479.772762     8478.517624
#
#         BS Error  Binomial Error       Date  % Binomial Error  % BS Error
# 0     398.701258      368.715014 2024-05-02         -0.338535   -0.366066
# 1       4.182208       15.506911 2024-05-02          0.006742   -0.001818
# 2     633.238379      608.395031 2024-05-02         -0.212088   -0.220748
# 3     628.425788      599.296972 2024-05-02         -0.213714   -0.224102
# 4     623.537317      590.998913 2024-05-02         -0.215646   -0.227519
# ...          ...             ...        ...               ...         ...
# 4689  178.072449      169.918360 2024-06-05         -0.047367   -0.049640
# 4690  222.949094      210.565830 2024-06-05         -0.055446   -0.058707
# 4691  190.083691      176.739565 2024-06-05         -0.045922   -0.049389
# 4692    9.796424       16.505054 2024-06-05         -0.010326    0.006129
# 4693  445.672762      444.417624 2024-06-05          0.055316    0.055473
#
# [4694 rows x 11 columns]
# Mean Error Black-Scholes:  -0.19438224454292086
# Mean Error Binomial:  -0.19560916167522577

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='% BS Error', data=results_df, label='BS Relative deviation', marker='o')
sns.lineplot(x='Date', y='% Binomial Error', data=results_df, label='Binomial Relative deviation', marker='s')
plt.xlabel('Date')
plt.ylabel('Relative deviations b/w model price and market price')
plt.title('Relative deviations Comparison Over Time')
plt.legend()
plt.savefig("1month_jan_feb_relative")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
def backtest(options_data, model_name='BS'):
    initial_cash = 10000  # starting capital
    cash = initial_cash
    positions = []
    transaction_log = []

    for index, row in options_data.iterrows():
        model_price = row[f'{model_name} Price']
        market_price = row['Market Price']
        strike_price = row['Strike']
        option_type = row['Type']
        expiry = row['Expiry']
        date = row['Date']

        # Decision making
        if model_price > market_price*1.05:  # Buying if model thinks it's undervalued
            if cash >= market_price:
                positions.append({'purchase_price': market_price, 'strike_price': strike_price, 'expiry': expiry, 'type': option_type})
                cash -= market_price
                transaction_log.append(f"Bought {option_type} for ${market_price} on {date}")

        # Closing/Selling positions
        for position in positions:
            if date >= position['expiry'] or model_price < market_price * 0.95:  # Selling if model thinks it's overvalued or at expiry
                cash += market_price
                positions.remove(position)
                transaction_log.append(f"Sold {position['type']} for ${market_price} on {date}")

    final_cash = cash + sum(pos['purchase_price'] for pos in positions)  # Liquidate all positions
    profit_loss = final_cash - initial_cash

    return profit_loss, transaction_log

# Backtest for both models
profit_loss_bs, transactions_bs = backtest(results_df, 'BS')
profit_loss_binomial, transactions_binomial = backtest(results_df, 'Binomial')

print("Profit/Loss for Black-Scholes Model:", profit_loss_bs)
# print("Transactions for Black-Scholes Model:", transactions_bs)
print("\nProfit/Loss for Binomial Model:", profit_loss_binomial)
# print("Transactions for Binomial Model:", transactions_binomial)
# Out:
# Profit/Loss for Black-Scholes Model: 11080.299999999974
#
# Profit/Loss for Binomial Model: 15720.149999999987
